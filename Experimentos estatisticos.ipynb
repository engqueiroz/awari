# %% [markdown]
# # Biblioteca

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Normal

# %%
normal = np.random.normal(size=10000)

# %%
normal.shape
# Out:
# (10000,)

# %%
plt.hist(normal,bins=100);

# %% [markdown]
# ### Teste QQ gráfico qq

# %%
import statsmodels.api as sm

# %%
sm.qqplot(normal, line="45");

# %% [markdown]
# #### Tamanho de amostra

# %%
normal_pequena = np.random.normal(size=30)

# %%
plt.hist(normal_pequena,bins=20);

# %%
sm.qqplot(normal_pequena, line="45");

# %% [markdown]
# # T - student

# %%
import seaborn as sns

# %%
t_student = np.random.standard_t(20,size=1000)

# %%
sns.distplot(t_student,label='DF=1');
plt.legend()
# Out:
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for df in [10,30,50]:
    t = np.random.standard_t(df,size=10000)
    sns.distplot(t,label=f'DF={df}');
    
plt.legend()
plt.show()
# Out:
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Binomial

# %%
from scipy.stats import binom

# %%
binomial = binom.rvs(n=100,p=0.5,size=1000)

# %%
binomial_unfair = binom.rvs(n=100,p=0.3,size=1000)

# %%
sns.distplot(binomial,label='normal');
sns.distplot(binomial_unfair,label='viciada');
plt.legend()
plt.show()
# Out:
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Poisson

# %%
poisson = np.random.poisson(lam=1,size=10000)

# %%
poisson_4 = np.random.poisson(lam=4,size=10000)

# %%
sns.distplot(poisson,label="lambda 1")
sns.distplot(poisson_4,label="lambda 4")
plt.legend()
plt.show()
# Out:
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Jarvis\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Testes de Hipotese

# %%
from scipy import stats

# %% [markdown]
# ## Testes normalidade

# %%
normal.shape
# Out:
# (10000,)

# %%
stats.shapiro(normal)
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\scipy\stats\morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# (0.9998794794082642, 0.9141920208930969)

# %% [markdown]
# ### Para poucas amostras

# %%
normal_pequena.shape
# Out:
# (30,)

# %%
stats.shapiro(normal_pequena)
# Out:
# (0.9705536365509033, 0.5544341802597046)

# %%
stats.shapiro(normal_pequena[0:10])
# Out:
# (0.9260753393173218, 0.4104168117046356)

# %% [markdown]
# ## Test T

# %%
stats.ttest_ind(normal,normal)
# Out:
# Ttest_indResult(statistic=0.0, pvalue=1.0)

# %%
### polimorfismo

# %%
5*5
# Out:
# 25

# %%
'a'*5
# Out:
# 'aaaaa'

# %%
normal.max()
# Out:
# 3.7167555831597054

# %%
normal.min()
# Out:
# -3.9651865626466

# %%
stats.ttest_ind(normal,0.1+normal)
# Out:
# Ttest_indResult(statistic=-7.0673934673290955, pvalue=1.6306521501690944e-12)

# %% [markdown]
# ## ANOVA

# %%
eps=1e-3

# %%
stats.f_oneway(normal+eps,normal-eps,normal,normal+2*eps)
# Out:
# F_onewayResult(statistic=0.016649350140681397, pvalue=0.9970751343383107)

# %%
stats.f_oneway(normal+eps,normal-eps,normal+0.1,normal+2*eps)
# Out:
# F_onewayResult(statistic=24.657687558350045, pvalue=6.217695336410359e-16)

# %% [markdown]
# ## Test Chi quadrado

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Resultado':['Cara','Coroa','Cara','Cara','Coroa']*10,
                   'Jogador':['A','A','B','B','A']*10})

# %%
df.shape
# Out:
# (50, 2)

# %%
contigencia = pd.crosstab(df['Jogador'],df['Resultado'])

# %%
contigencia
# Out:
# Resultado  Cara  Coroa
# Jogador
# A            10     20
# B            20      0

# %%
stats.chi2_contingency(contigencia)
# Out:
# (19.53125,
#  9.896734625245616e-06,
#  1,
#  array([[18., 12.],
#         [12.,  8.]]))

# %% [markdown]
# # Modelando Teste A/B

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
df_iris = pd.DataFrame(iris['data'],columns=iris['feature_names'])

# %%
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df_iris.shape
# Out:
# (150, 4)

# %%
df_iris['especie'] = [iris['target_names'][x] for x in iris['target']]

# %%
df_iris.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        especie
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %% [markdown]
# ## Plots

# %%
import seaborn as sns

# %% [markdown]
# ### Scatter plot das caracteristicas

# %%
df_iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'especie'],
#       dtype='object')

# %%
sns.scatterplot(data=df_iris,x='sepal length (cm)', y='sepal width (cm)', hue='especie')
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
sns.scatterplot(data=df_iris,x='petal length (cm)', y='petal width (cm)', hue='especie')
# Out:
# <AxesSubplot:xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %% [markdown]
# ## Pointplot

# %%
df_iris.columns[:-1]
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots(4,1,figsize=(12,8))
for idx, caracteristica in enumerate(df_iris.columns[:-1]):
    sns.pointplot(data=df_iris,y=caracteristica, x='especie',ax=ax[idx])
plt.show()

# %% [markdown]
# ## boxplot

# %%
fig,ax = plt.subplots(4,1,figsize=(8,14))
for idx, caracteristica in enumerate(df_iris.columns[:-1]):
    sns.boxplot(data=df_iris,y=caracteristica, x='especie',ax=ax[idx])
plt.show()

# %% [markdown]
# # Geração de Hipóteses

# %% [markdown]
# ## Hipótese 1
#
# As caracteristicas das especies são bons discriminantes ( Preditores) da categoria da flor?

# %% [markdown]
# ### Anova em todas as caracteristicas

# %%
for caracteristica in df_iris.columns[:-1]:
    
    anova, pvalor = stats.f_oneway(df_iris.loc[(df_iris['especie']=='setosa'),caracteristica],
                                   df_iris.loc[(df_iris['especie']=='versicolor'),caracteristica],
                                   df_iris.loc[(df_iris['especie']=='virginica'),caracteristica])
    
    print(f"Para a caracteristica {caracteristica}: Anova: {anova}, p-value: {pvalor}")
# Out:
# Para a caracteristica sepal length (cm): Anova: 119.26450218450468, p-value: 1.6696691907693826e-31
# Para a caracteristica sepal width (cm): Anova: 49.160040089612075, p-value: 4.492017133309115e-17
# Para a caracteristica petal length (cm): Anova: 1180.161182252981, p-value: 2.8567766109615584e-91
# Para a caracteristica petal width (cm): Anova: 960.007146801809, p-value: 4.169445839443116e-85

# %% [markdown]
# ### Testando todos os cenarios

# %%
from itertools import permutations, combinations

# %%
[x for x in combinations(['setosa','virginica','versicolor'],2)]
# Out:
# [('setosa', 'virginica'),
#  ('setosa', 'versicolor'),
#  ('virginica', 'versicolor')]

# %%
for caracteristica in df_iris.columns[:-1]:
    
    resultado_teste = []
    
    for esp1, esp2 in combinations(['setosa','virginica','versicolor'],2):
        _, pvalue = stats.ttest_ind(df_iris.loc[df_iris['especie']==esp1, caracteristica],
                                    df_iris.loc[df_iris['especie']==esp2, caracteristica])
        
        if pvalue < 0.05:
            resultado_teste.append(True)
        else:
            resultado_teste.append(False)
    
    if sum(resultado_teste) == 3:
        print(f'A caracteristica {caracteristica} é um bom preditor')
    else:
        print(f'A caracteristica {caracteristica} não é um bom preditor')
# Out:
# A caracteristica sepal length (cm) é um bom preditor
# A caracteristica sepal width (cm) é um bom preditor
# A caracteristica petal length (cm) é um bom preditor
# A caracteristica petal width (cm) é um bom preditor

# %% [markdown]
# ## Testes de médias não-paramétrico

# %%
#Kolmogorov-smirnov

# %%
for caracteristica in df_iris.columns[:-1]:
    
    resultado_teste = []
    
    for esp1, esp2 in combinations(['setosa','virginica','versicolor'],2):
        _, pvalue = stats.ks_2samp(df_iris.loc[df_iris['especie']==esp1, caracteristica],
                                    df_iris.loc[df_iris['especie']==esp2, caracteristica])
        
        if pvalue < 0.05:
            resultado_teste.append(True)
        else:
            resultado_teste.append(False)
    
    if sum(resultado_teste) == 3:
        print(f'A caracteristica {caracteristica} é um bom preditor')
    else:
        print(f'A caracteristica {caracteristica} não é um bom preditor, {resultado_teste}')
# Out:
# A caracteristica sepal length (cm) é um bom preditor
# A caracteristica sepal width (cm) não é um bom preditor, [True, True, False]
# A caracteristica petal length (cm) é um bom preditor
# A caracteristica petal width (cm) é um bom preditor

# %% [markdown]
# ## Hipótese 2
#
# Existem diferenças relevantes entre a virgina e versicolor que as separem

# %% [markdown]
# Repondida pelo teste do KS, é verdadeira exceto para `sepal width`
